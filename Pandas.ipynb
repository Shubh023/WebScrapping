# %%
import numpy as np
import pandas as pd

df = pd.read_csv('data.csv')
df
# Out:
#                                             Respondent  \
# 0                                                    1
# 1                                               Server
# 2                                              descent
# 3                                    job opportunities
# 4                                                 Core
# ..                                                 ...
# 150  \t  friend;Go for a walk or other physical act...
# 151                                          \t  later
# 152                                      \t  influence
# 153                                  \t  times per day
# 154                                 \t  than last year
#
#                                     MainBranch  \
# 0               I am a developer by profession
# 1    Elasticsearch;Microsoft SQL Server;Oracle
# 2                                          Man
# 3                       C#;HTML/CSS;JavaScript
# 4       Microsoft Teams;Microsoft Azure;Trello
# ...
